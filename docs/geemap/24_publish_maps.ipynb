# %% [markdown]
# <a href="https://githubtocolab.com/giswqs/geemap/blob/master/examples/notebooks/24_publish_maps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>
#
# Uncomment the following line to install [geemap](https://geemap.org) if needed.

# %%
# !pip install geemap

# %% [markdown]
# To follow this tutorial, you will need to [sign up](https://datapane.com/accounts/signup/) for an account with <https://datapane.com>, then install and authenticate the `datapane` Python package. More information can be found [here](https://docs.datapane.com/tutorials/tut-getting-started).
#
# - `pip install datapane`
# - `datapane login`
# - `datapane ping`

# %%
import os
import ee
import geemap.foliumap as geemap
#import ipywidgets as widgets
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Initialize Earth Engine
import ee
try:
    ee.Initialize()
except Exception as e:
    ee.Authenticate()
    ee.Initialize(project="ee-zekuwany")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Map = geemap.Map()
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1b38a0e0d32d2b9de897b72721ee6c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1b38a0e0d32d2b9de897b72721ee6c9&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1b38a0e0d32d2b9de897b72721ee6c9 = L.map(
#                 &quot;map_d1b38a0e0d32d2b9de897b72721ee6c9&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6ae62c437f74a95980dd6a6d150ea48f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6ae62c437f74a95980dd6a6d150ea48f.addTo(map_d1b38a0e0d32d2b9de897b72721ee6c9);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_d1b38a0e0d32d2b9de897b72721ee6c9);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_f9264beebdf617adbce1dca2704923dc =
#                     new L.featureGroup().addTo(
#                         map_d1b38a0e0d32d2b9de897b72721ee6c9
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_f9264beebdf617adbce1dca2704923dc;
#             var draw_control_f9264beebdf617adbce1dca2704923dc = new L.Control.Draw(
#                 options
#             ).addTo( map_d1b38a0e0d32d2b9de897b72721ee6c9 );
#             map_d1b38a0e0d32d2b9de897b72721ee6c9.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_f9264beebdf617adbce1dca2704923dc.addLayer(layer);
#             });
#             map_d1b38a0e0d32d2b9de897b72721ee6c9.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_f9264beebdf617adbce1dca2704923dc.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_325cc4e8d747fda0231a0d1ae3b603e4 = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_325cc4e8d747fda0231a0d1ae3b603e4 = geocoderOpts_geocoder_325cc4e8d747fda0231a0d1ae3b603e4[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_325cc4e8d747fda0231a0d1ae3b603e4 = L.Control.Geocoder[ geocoderName_geocoder_325cc4e8d747fda0231a0d1ae3b603e4 ](
#                 geocoderOpts_geocoder_325cc4e8d747fda0231a0d1ae3b603e4[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_325cc4e8d747fda0231a0d1ae3b603e4[&quot;geocoder&quot;] = customGeocoder_geocoder_325cc4e8d747fda0231a0d1ae3b603e4;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_325cc4e8d747fda0231a0d1ae3b603e4
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_325cc4e8d747fda0231a0d1ae3b603e4[&#x27;zoom&#x27;] || map_d1b38a0e0d32d

# %%
roi_shp = '/content/geospatial-notebooks/docs/data/Gara_Mullata_Park.shp'
roi = geemap.shp_to_ee(roi_shp)
Map.addLayer(roi, {}, 'GMP')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# No module named 'pycrs'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_160/3194500912.py in <cell line: 0>()
#       1 roi_shp = '/content/geospatial-notebooks/docs/data/Gara_Mullata_Park.shp'
#       2 roi = geemap.shp_to_ee(roi_shp)
# ----> 3 Map.addLayer(roi, {}, 'GMP')
#
# /usr/local/lib/python3.12/dist-packages/geemap/foliumap.py in add_layer(self, ee_object, vis_params, name, shown, opacity, **kwargs)
#     278         """
#     279
# --> 280         layer = EEFoliumTileLayer(ee_object, vis_params, name, shown, opacity, **kwargs)
#     281         layer.add_to(self)
#     282         arc_add_layer(layer.url_format, name, shown, opacity)
#
# /usr/local/lib/python3.12/dist-packages/geemap/ee_tile_layers.py in __init__(self, ee_object, vis_params, name, shown, opacity, **kwargs)
#     152                 number between 0 and 1. Defaults to 1.
#     153         """
# --> 154         self.url_format = _get_tile_url_format(
#     155             ee_object, _validate_vis_params(vis_params)
#     156         )
#
# /usr/local/lib/python3.12/dist-packages/geemap/ee_tile_layers.py in _get_tile_url_format(ee_object, vis_params)
#      33         str: The tile URL format.
#      34     """
# ---> 35     image = _ee_object_to_image(ee_object, vis_params)
#      36     map_id_dict = ee.Image(image).getMapId(vis_params)
#      37     return map_id_dict["tile_fetcher"].url_format
#
# /usr/local/lib/python3.12/dist-packages/geemap/ee_tile_layers.py in _ee_object_to_image(ee_object, vis_params)
#      96     elif isinstance(ee_object, ee.ImageCollection):
#      97         return ee_object.mosaic()
# ---> 98     raise AttributeError(
#      99         f"\n\nCannot add an object of type {ee_object.__class__.__name__} to the map."
#     100     )
#
# AttributeError:
#
# Cannot add an object of type NoneType to the map.

# %%
# Create a map centered at (lat, lon).
Map = geemap.Map(center=[41.73, 9.24], zoom=14)

# Use an elevation dataset and terrain functions to create
# a custom visualization of topography.

# Load a global elevation image.
elev = ee.Image('USGS/GMTED2010')

# Zoom to an area of interest.
Map.setCenter(41.73, 9.24, 13)

# Add the elevation to the map.
Map.addLayer(elev, {}, 'elev')

# Use the terrain algorithms to compute a hillshade with 8-bit values.
shade = ee.Terrain.hillshade(elev)
Map.addLayer(shade, {}, 'hillshade', False)

# Create a "sea" variable to be used for cartographic purposes
sea = elev.lte(0)
Map.addLayer(sea.mask(sea), {'palette': '000022'}, 'sea', False)

# Create a custom elevation palette from hex strings.
elevationPalette = ['006600', '002200', 'fff700', 'ab7634', 'c4d0ff', 'ffffff']
# Use these visualization parameters, customized by location.
visParams = {'min': 1, 'max': 3000, 'palette': elevationPalette}

# Create a mosaic of the sea and the elevation data
visualized = ee.ImageCollection(
    [
        # Mask the elevation to get only land
        elev.mask(sea.Not()).visualize(**visParams),
        # Use the sea mask directly to display sea.
        sea.mask(sea).visualize(**{'palette': '000022'}),
    ]
).mosaic()

# Note that the visualization image doesn't require visualization parameters.
Map.addLayer(visualized, {}, 'elev palette', False)

# Convert the visualized elevation to HSV, first converting to [0, 1] data.
hsv = visualized.divide(255).rgbToHsv()
# Select only the hue and saturation bands.
hs = hsv.select(0, 1)
# Convert the hillshade to [0, 1] data, as expected by the HSV algorithm.
v = shade.divide(255)
# Create a visualization image by converting back to RGB from HSV.
# Note the cast to byte in order to export the image correctly.
rgb = hs.addBands(v).hsvToRgb().multiply(255).byte()
Map.addLayer(rgb, {}, 'styled')

states = ee.FeatureCollection('TIGER/2018/States')
Map.addLayer(ee.Image().paint(states, 0, 2), {}, "US States")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# /usr/local/lib/python3.12/dist-packages/ee/deprecation.py:207: DeprecationWarning:
#
# Attention required for USGS/GMTED2010! You are using a deprecated asset.
# To make sure your code keeps working, please update it.
# Learn more: https://developers.google.com/earth-engine/datasets/catalog/USGS_GMTED2010
#
#   warnings.warn(warning, category=DeprecationWarning)

# %%
# Display the map.
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a122020ebc53bdbd726ec605dcd297f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a122020ebc53bdbd726ec605dcd297f9&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a122020ebc53bdbd726ec605dcd297f9 = L.map(
#                 &quot;map_a122020ebc53bdbd726ec605dcd297f9&quot;,
#                 {
#                     center: [41.73, 9.24],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;eeInitialize&quot;: true,
#   &quot;addGoogleMap&quot;: false,
#   &quot;pluginLatlngpopup&quot;: false,
#   &quot;pluginFullscreen&quot;: true,
#   &quot;pluginDraw&quot;: true,
#   &quot;DrawExport&quot;: false,
#   &quot;pluginMinimap&quot;: false,
#   &quot;locateControl&quot;: false,
#   &quot;searchControl&quot;: true,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ca20499f8ce10053a8758e55e0926e4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9ca20499f8ce10053a8758e55e0926e4.addTo(map_a122020ebc53bdbd726ec605dcd297f9);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_a122020ebc53bdbd726ec605dcd297f9);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_43963e1a5dea1bbef456ee7c1bce4e45 =
#                     new L.featureGroup().addTo(
#                         map_a122020ebc53bdbd726ec605dcd297f9
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_43963e1a5dea1bbef456ee7c1bce4e45;
#             var draw_control_43963e1a5dea1bbef456ee7c1bce4e45 = new L.Control.Draw(
#                 options
#             ).addTo( map_a122020ebc53bdbd726ec605dcd297f9 );
#             map_a122020ebc53bdbd726ec605dcd297f9.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_43963e1a5dea1bbef456ee7c1bce4e45.addLayer(layer);
#             });
#             map_a122020ebc53bdbd726ec605dcd297f9.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_43963e1a5dea1bbef456ee7c1bce4e45.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_9ba09ecf5fc48464b9e961589f64f5cb = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_9ba09ecf5fc48464b9e961589f64f5cb = geocoderOpts_geocoder_9ba09ecf5fc48464b9e961589f64f5cb[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_9ba09ecf5fc48464b9e961589f64f5cb = L.Control.Geocoder[ geocoderName_geocoder_9ba09ecf5fc48464b9e961589f64f5cb ](
#                 geocoderOpts_geocoder_9ba09ecf5fc48464b9e961589f64f5cb[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_9ba09ecf5fc48464b9e961589f64f5cb[&quot;geocoder&quot;] = customGeocoder_geocoder_9ba09ecf5fc48464b9e961589f64f5cb;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_9ba09ecf5fc48464b9e961589f64f5cb
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_9ba09ecf5fc48464b9e961589f64f5cb[&#x27;zoom&#x27;] || map_a122020ebc

# %%
Map.publish(
    name='Terrain Visualization',
    description='A folium map with Earth Engine data layers',
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/geemap/foliumap.py in publish(self, name, description, source_url, tags, source_file, open, formatting, token, **kwargs)
#    1898         try:
# -> 1899             import datapane as dp
#    1900         except Exception:
#
# ModuleNotFoundError: No module named 'datapane'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_160/1501702082.py in <cell line: 0>()
# ----> 1 Map.publish(
#       2     name='Terrain Visualization',
#       3     description='A folium map with Earth Engine data layers',
#       4 )
#
# /usr/local/lib/python3.12/dist-packages/geemap/foliumap.py in publish(self, name, description, source_url, tags, source_file, open, formatting, token, **kwargs)
#    1900         except Exception:
#    1901             webbrowser.open_new_tab("https://docs.datapane.com/")
# -> 1902             raise ImportError(
#    1903                 "The datapane Python package is not installed. You need to install and authenticate datapane first."
#    1904             )
#
# ImportError: The datapane Python package is not installed. You need to install and authenticate datapane first.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
